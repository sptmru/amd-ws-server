# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
RECORDINGS_PATH = "/Users/sptm/dev/personal/beep-detection-dataset/audiofiles"
PICKLE_FILE_NAME  = "dataframe"

# %%
#compute
import glob, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import uuid

os.chdir(RECORDINGS_PATH)

def process(file, label):
  try:
    print("processing {}".format(file))
    
    # here kaiser_fast is a technique used for faster extraction
    X, sample_rate = librosa.load(file, res_type='kaiser_fast') 
    duration = librosa.get_duration(X, sample_rate)
    stft = np.abs(librosa.stft(X))
    mfccs_40 = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)    
    mel = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate, n_mels=128,fmax=8000).T,axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
    sr=sample_rate).T,axis=0)

    row = pd.Series({'file_path':file,'mfccs_40':mfccs_40, 'chroma':chroma, 'mel':mel, 'contrast':contrast, 'tonnetz':tonnetz, 'duration':duration,'label':label},name=7)
    df.loc[len(df)] = row  
    
  except Exception as e:
    print("Error encountered while parsing file: ", file)
    print(f"Exception: {e}")


def download_files(path, label, max=100):
  index = 0
  for file in glob.glob(path):
    if index <=max:
      row = process(file, label)
      df.loc[len(df)] = row
      index = index +1

  #save the df for reusabality
  df.to_pickle(PICKLE_FILE_NAME+".pkl")

# %%
df = pd.DataFrame(columns=['file_path', 'mfccs_40', 'chroma', 'mel','contrast','tonnetz', 'duration','label'])
df = df.fillna(0) # with 0s rather than NaNs

# os.chdir(RECORDINGS_PATH)
download_files("beep/*.wav", label="beep")
download_files("voice/*.wav", label="speech")
# download_files("speech/*.wav", label="speech")
# Out:
# processing beep/overdrive_beep_1000_0.5_1.1.wav
# processing beep/beep_500_0.5_1.1.wav
# processing beep/beep_1500_0.5_1.2.wav
# processing beep/whitenoise_beep_1000_1_1.4.wav
# processing beep/overdrive_beep_1000_0.2_0.9.wav
# /Users/sptm/.pyenv/versions/amd/lib/python3.6/site-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# processing beep/whitenoise_beep_1500_1_1.1.wav
# processing beep/beep_500_0.2_0.9.wav
# processing beep/beep_500_0.2_0.8.wav
# processing beep/whitenoise_beep_1500_1_1.0.wav
# processing beep/overdrive_beep_1000_0.2_0.8.wav
# processing beep/whitenoise_beep_1000_1_1.5.wav
# processing beep/beep_1500_0.5_1.3.wav
# processing beep/beep_500_0.5_1.0.wav
# processing beep/overdrive_beep_1000_0.5_1.0.wav
# processing beep/beep_500_0.5_1.2.wav
# processing beep/overdrive_beep_1000_0.5_1.2.wav
# processing beep/whitenoise_beep_1000_0.2_1.5.wav
# processing beep/beep_1500_0.5_1.1.wav
# processing beep/whitenoise_beep_500_1_1.5.wav
# processing beep/whitenoise_beep_1500_1_1.2.wav
# processing beep/beep_1500_0.2_0.9.wav
# processing beep/beep_1000_1_0.8.wav
# processing beep/overdrive_beep_1500_0.2_1.3.wav
# processing beep/overdrive_beep_1500_0.2_1.2.wav
# processing beep/beep_1000_1_0.9.wav
# processing beep/overdrive_beep_1500_1_1.3.wav
# processing beep/whitenoise_beep_500_0.2_1.1.wav
# processing beep/beep_1000_0.2_1.1.wav
# processing beep/overdrive_beep_500_0.5_0.8.wav
# processing beep/whitenoise_beep_1500_0.5_1.5.wav
# processing beep/overdrive_beep_500_0.2_1.0.wav
# processing beep/whitenoise_beep_500_0.5_0.9.wav
# processing beep/beep_1000_0.5_0.9.wav
# processing beep/overdrive_beep_500_0.2_1.2.wav
# processing beep/overdrive_beep_1000_1_1.4.wav
# processing beep/overdrive_beep_1500_0.5_0.8.wav
# processing beep/beep_1000_0.2_1.3.wav
# processing beep/whitenoise_beep_500_0.2_1.3.wav
# processing beep/overdrive_beep_500_1_0.8.wav
# processing beep/overdrive_beep_1500_1_1.1.wav
# processing beep/beep_500_1_0.9.wav
# processing beep/overdrive_beep_1500_0.2_1.0.wav
# processing voice/hello_padded_1.2.wav
# processing voice/hello_padded_1.3.wav
# processing voice/hello_padded_1.1.wav
# processing voice/ad_padded_0.8.wav
# processing voice/att_padded_0.8.wav
# processing voice/att_padded_0.9.wav
# processing voice/ad_padded_0.9.wav
# processing voice/hello_padded_1.0.wav
# processing voice/hello_padded_1.4.wav
# processing voice/hello_padded_1.5.wav
# processing voice/bal_padded_0.9.wav
# processing voice/bal_padded_0.8.wav
# processing voice/att_padded_1.1.wav
# processing voice/hello_padded_0.8.wav
# processing voice/ad_padded_1.1.wav
# processing voice/ad_padded_1.0.wav
# processing voice/hello_padded_0.9.wav
# processing voice/att_padded_1.0.wav
# processing voice/att_padded_1.2.wav
# processing voice/ad_padded_1.2.wav
# processing voice/ad_padded_1.3.wav
# processing voice/att_padded_1.3.wav
# processing voice/att_padded_1.4.wav
# processing voice/ad_padded_1.4.wav
# processing voice/ad_padded_1.5.wav
# processing voice/att_padded_1.5.wav
# processing voice/bal_padded_1.5.wav
# processing voice/bal_padded_1.4.wav
# processing voice/bal_padded_1.3.wav
# processing voice/bal_padded_1.2.wav
# processing voice/bal_padded_1.0.wav
# processing voice/bal_padded_1.1.wav

# %%
df.dropna(inplace=True)

# %%
df.label.value_counts()
# Out:
# beep      101
# speech     32
# Name: label, dtype: int64

# %%
df.to_pickle("amd-df-new"+".pkl")

# %%
df1 = pd.read_pickle("amd-df-new.pkl")

# %%
df1
# Out:
#                                 file_path  \
# 0    beep/overdrive_beep_1000_0.5_1.1.wav
# 2               beep/beep_500_0.5_1.1.wav
# 4              beep/beep_1500_0.5_1.2.wav
# 6     beep/whitenoise_beep_1000_1_1.4.wav
# 8    beep/overdrive_beep_1000_0.2_0.9.wav
# ..                                    ...
# 256              voice/bal_padded_1.4.wav
# 258              voice/bal_padded_1.3.wav
# 260              voice/bal_padded_1.2.wav
# 262              voice/bal_padded_1.0.wav
# 264              voice/bal_padded_1.1.wav
#
#                                               mfccs_40  \
# 0    [-648.7732023402463, 20.740027296822582, -5.91...
# 2    [-480.8374331960098, 10.282236333040958, 3.655...
# 4    [-479.43226392005187, 8.823462420491044, -7.00...
# 6    [-510.32630840985456, 116.5288260006204, -61.4...
# 8    [-633.8929389641592, 13.329635016242825, -1.71...
# ..                                                 ...
# 256  [-643.3035440315198, 50.17073795408048, -13.48...
# 258  [-640.6134553240412, 49.41991871458323, -13.00...
# 260  [-643.5028173970785, 49.62647644149001, -13.29...
# 262  [-639.6619958876586, 49.431769369730304, -13.2...
# 264  [-641.0992938612844, 50.59337566879583, -13.34...
#
#                                                 chroma  \
# 0    [0.7426175694626616, 0.7781152791222149, 0.824...
# 2    [0.7520259169180716, 0.7858180386260021, 0.833...
# 4    [0.7113293586172407, 0.7758262316678054, 0.829...
# 6    [0.6301969016301114, 0.6376268612024417, 0.672...
# 8    [0.7774235039606778, 0.8326985399960135, 0.887...
# ..                                                 ...
# 256  [0.6786547529262393, 0.722390771697396, 0.7794...
# 258  [0.6821662001968082, 0.7244291644417343, 0.778...
# 260  [0.6821463124001733, 0.7272038385126283, 0.784...
# 262  [0.6787548455408147, 0.725487897570125, 0.7846...
# 264  [0.6873891412753846, 0.7385738956459449, 0.796...
#
#                                                    mel  \
# 0    [0.0026247237229858823, 0.0006950270827125862,...
# 2    [0.031262080105508704, 0.03167270253963774, 0....
# 4    [0.007056509943697298, 0.005333584908935328, 0...
# 6    [0.0015886821479110318, 0.0009468671348235026,...
# 8    [0.003848214383519196, 0.0009013721193474459, ...
# ..                                                 ...
# 256  [0.0036771875265813993, 0.002992508627403655, ...
# 258  [0.0036588639857885945, 0.0029854629096608127,...
# 260  [0.003682317980418147, 0.0030010767396318034, ...
# 262  [0.0038506553143079544, 0.0033567325929315574,...
# 264  [0.004241579436047557, 0.0035895606491686983, ...
#
#                                               contrast  \
# 0    [56.51764945998396, 16.33025638875271, 16.9291...
# 2    [49.83079341143087, 15.750314235349212, 19.078...
# 4    [54.4286362849155, 18.782510605942036, 19.1482...
# 6    [22.677968639075868, 12.218876538183435, 13.80...
# 8    [61.9167246932255, 19.312564563129726, 19.5758...
# ..                                                 ...
# 256  [48.19586829682009, 13.231563955135925, 13.530...
# 258  [48.18413469547728, 13.86075000623263, 13.9880...
# 260  [50.23413382319893, 14.989180820724524, 15.229...
# 262  [49.82494699785795, 13.923664807019376, 14.076...
# 264  [48.254214700765985, 13.232067605276573, 13.62...
#
#                                                tonnetz  duration   label
# 0    [0.007893745237780317, 0.025323062200878606, 0...      5.08    beep
# 2    [0.00024741614877230386, 0.03390149680750231, ...      5.06    beep
# 4    [0.00016978951816631077, 0.02980498970033441, ...      5.04    beep
# 6    [0.004513859067965158, -0.003625802336170082, ...      5.06    beep
# 8    [0.002519536997647612, 0.0634943357789246, 0.0...      5.06    beep
# ..                                                 ...       ...     ...
# 256  [-0.008224373960754879, 0.04492690807961658, 0...      5.06  speech
# 258  [-0.027933759869567823, 0.02952639338015452, 0...      5.08  speech
# 260  [0.004242328373475395, 0.036245135120524345, 0...      5.06  speech
# 262  [-0.03160937857326705, 0.028544683763556372, 0...      5.06  speech
# 264  [0.005028571890551516, 0.014667573077975794, 0...      5.06  speech
#
# [133 rows x 8 columns]
